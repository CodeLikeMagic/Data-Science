# %%
#@title ########################### Updating Rows and Columns ---- Modifying Daa with DataFrames #################

# %%
import pandas as pd
import matplotlib

# %%
df = pd.read_csv('/content/drive/MyDrive/sample_data/sample-data-order-stream.csv')

# %%
df.columns
# Out:
# Index(['orderId', 'orderDate', 'shipDate', 'shipMode', 'customerId', 'segment',
#        'cityNames', 'countryNames', 'postalCode', 'item', 'quantity', 'cost',
#        'total', 'profit'],
#       dtype='object')

# %%
### df.columns = ['id', 'order-placed', 'to-be-delivered']
#give custom names to columns
### df

# %%
df.columns = [x.upper() for x in df.columns]

#df.columns = df.columns.str.replace(' ', '_')

df
# Out:
#      ORDERID  ORDERDATE   SHIPDATE      SHIPMODE  CUSTOMERID   SEGMENT  \
# 0         10  3/14/2023  3/23/2023   FIRST CLASS         220  APPARELS
# 1         16  3/14/2023  3/22/2023  SECOND CLASS         325  APPARELS
# 2         21  3/14/2023  3/20/2023   FIRST CLASS         245  APPARELS
# 3         23  3/14/2023  3/20/2023   FIRST CLASS         158  APPARELS
# 4         36  3/14/2023  3/20/2023      STANDARD         364  APPARELS
# ..       ...        ...        ...           ...         ...       ...
# 137      129  3/14/2023  3/23/2023   FIRST CLASS         218  APPARELS
# 138      145  3/14/2023  3/21/2023   FIRST CLASS         361  APPARELS
# 139      157  3/14/2023  3/20/2023   FIRST CLASS         138  APPARELS
# 140      160  3/14/2023  3/20/2023      STANDARD         386  APPARELS
# 141      167  3/14/2023  3/23/2023  SECOND CLASS         163  APPARELS
#
#     CITYNAMES COUNTRYNAMES  POSTALCODE         ITEM  QUANTITY  COST  TOTAL  \
# ...

# %%
df.rename(columns={'SEGMENT':'CATEGORY'}, inplace=True)

# %%
df
# Out:
#      ORDERID  ORDERDATE   SHIPDATE      SHIPMODE  CUSTOMERID  CATEGORY  \
# 0         10  3/14/2023  3/23/2023   FIRST CLASS         220  APPARELS
# 1         16  3/14/2023  3/22/2023  SECOND CLASS         325  APPARELS
# 2         21  3/14/2023  3/20/2023   FIRST CLASS         245  APPARELS
# 3         23  3/14/2023  3/20/2023   FIRST CLASS         158  APPARELS
# 4         36  3/14/2023  3/20/2023      STANDARD         364  APPARELS
# ..       ...        ...        ...           ...         ...       ...
# 137      129  3/14/2023  3/23/2023   FIRST CLASS         218  APPARELS
# 138      145  3/14/2023  3/21/2023   FIRST CLASS         361  APPARELS
# 139      157  3/14/2023  3/20/2023   FIRST CLASS         138  APPARELS
# 140      160  3/14/2023  3/20/2023      STANDARD         386  APPARELS
# 141      167  3/14/2023  3/23/2023  SECOND CLASS         163  APPARELS
#
#     CITYNAMES COUNTRYNAMES  POSTALCODE         ITEM  QUANTITY  COST  TOTAL  \
# ...

# %%
df.loc[4]

### df.loc[4] = ['', '', '', '']
#give all values,   replace values with new values for the existing record
# Out:
# ORDERID                36
# ORDERDATE       3/14/2023
# SHIPDATE        3/20/2023
# SHIPMODE         STANDARD
# CUSTOMERID            364
# CATEGORY         APPARELS
# CITYNAMES        GUWAHATI
# COUNTRYNAMES        INDIA
# POSTALCODE         110001
# ITEM            KURTA SET
# QUANTITY                7
# COST                  169
# TOTAL                1183
# PROFIT                 35
# Name: 4, dtype: object

# %%
df.loc[4, ['COST', 'PROFIT']] = [1697, 567]

# %%
df.loc[4]
# Out:
# ORDERID                36
# ORDERDATE       3/14/2023
# SHIPDATE        3/20/2023
# SHIPMODE         STANDARD
# CUSTOMERID            364
# CATEGORY         APPARELS
# CITYNAMES        GUWAHATI
# COUNTRYNAMES        INDIA
# POSTALCODE         110001
# ITEM            KURTA SET
# QUANTITY                7
# COST                 1697
# TOTAL                1183
# PROFIT                567
# Name: 4, dtype: object

# %%
df.loc[4, 'ITEM'] = 'ANARKALI SUIT'

# %%
df.loc[4]
# Out:
# ORDERID                    36
# ORDERDATE           3/14/2023
# SHIPDATE            3/20/2023
# SHIPMODE             STANDARD
# CUSTOMERID                364
# CATEGORY             APPARELS
# CITYNAMES            GUWAHATI
# COUNTRYNAMES            INDIA
# POSTALCODE             110001
# ITEM            ANARKALI SUIT
# QUANTITY                    7
# COST                     1697
# TOTAL                    1183
# PROFIT                    567
# Name: 4, dtype: object

# %%
#another way

df.at[4, 'ITEM'] = 'SNEAKERS'

df
# Out:
#      ORDERID  ORDERDATE   SHIPDATE      SHIPMODE  CUSTOMERID  CATEGORY  \
# 0         10  3/14/2023  3/23/2023   FIRST CLASS         220  APPARELS
# 1         16  3/14/2023  3/22/2023  SECOND CLASS         325  APPARELS
# 2         21  3/14/2023  3/20/2023   FIRST CLASS         245  APPARELS
# 3         23  3/14/2023  3/20/2023   FIRST CLASS         158  APPARELS
# 4         36  3/14/2023  3/20/2023      STANDARD         364  APPARELS
# ..       ...        ...        ...           ...         ...       ...
# 137      129  3/14/2023  3/23/2023   FIRST CLASS         218  APPARELS
# 138      145  3/14/2023  3/21/2023   FIRST CLASS         361  APPARELS
# 139      157  3/14/2023  3/20/2023   FIRST CLASS         138  APPARELS
# 140      160  3/14/2023  3/20/2023      STANDARD         386  APPARELS
# 141      167  3/14/2023  3/23/2023  SECOND CLASS         163  APPARELS
#
#     CITYNAMES COUNTRYNAMES  POSTALCODE         ITEM  QUANTITY  COST  TOTAL  \
# ...

# %%
filter1 = (df['SHIPMODE'] == 'STANDARD')

df[filter1]['CITYNAMES'] = 'MUMBAI'
# Out:
# <ipython-input-15-e2ac12bf884d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[filter1]['CITYNAMES'] = 'MUMBAI'

# %%
filter1 = (df['SHIPMODE'] == 'STANDARD')

df.loc[filter1, 'CITYNAMES'] = 'MUMBAI'

# %%
df[filter1]
# Out:
#      ORDERID  ORDERDATE   SHIPDATE  SHIPMODE  CUSTOMERID  CATEGORY CITYNAMES  \
# 4         36  3/14/2023  3/20/2023  STANDARD         364  APPARELS    MUMBAI
# 5         38  3/14/2023  3/23/2023  STANDARD         176  APPARELS    MUMBAI
# 12        99  3/14/2023  3/19/2023  STANDARD         192  APPARELS    MUMBAI
# 14       112  3/14/2023  3/19/2023  STANDARD         267  APPARELS    MUMBAI
# 15       117  3/14/2023  3/20/2023  STANDARD         356  APPARELS    MUMBAI
# 39       112  3/14/2023  3/20/2023  STANDARD         302  APPARELS    MUMBAI
# 40       118  3/14/2023  3/19/2023  STANDARD         393  APPARELS    MUMBAI
# 41       120  3/14/2023  3/24/2023  STANDARD         391  APPARELS    MUMBAI
# 47       145  3/14/2023  3/19/2023  STANDARD         296  APPARELS    MUMBAI
# 54       190  3/14/2023  3/24/2023  STANDARD         247  APPARELS    MUMBAI
# 55       194  3/14/2023  3/22/2023  STANDARD         106  APPARELS    MUMBAI
# ...

# %%
df['CATEGORY'] = df['CATEGORY'].str.lower()

# %%
df
# Out:
#      ORDERID  ORDERDATE   SHIPDATE      SHIPMODE  CUSTOMERID  CATEGORY  \
# 0         10  3/14/2023  3/23/2023   FIRST CLASS         220  apparels
# 1         16  3/14/2023  3/22/2023  SECOND CLASS         325  apparels
# 2         21  3/14/2023  3/20/2023   FIRST CLASS         245  apparels
# 3         23  3/14/2023  3/20/2023   FIRST CLASS         158  apparels
# 4         36  3/14/2023  3/20/2023      STANDARD         364  apparels
# ..       ...        ...        ...           ...         ...       ...
# 137      129  3/14/2023  3/23/2023   FIRST CLASS         218  apparels
# 138      145  3/14/2023  3/21/2023   FIRST CLASS         361  apparels
# 139      157  3/14/2023  3/20/2023   FIRST CLASS         138  apparels
# 140      160  3/14/2023  3/20/2023      STANDARD         386  apparels
# 141      167  3/14/2023  3/23/2023  SECOND CLASS         163  apparels
#
#     CITYNAMES COUNTRYNAMES  POSTALCODE         ITEM  QUANTITY  COST  TOTAL  \
# ...

# %%
#####
#apply
#---dataframe,  series object


df['ITEM'].apply(len)
# Out:
# 0       9
# 1       5
# 2       7
# 3       5
# 4       8
#        ..
# 137    11
# 138     5
# 139     5
# 140     4
# 141     8
# Name: ITEM, Length: 142, dtype: int64

# %%
def update_case(CATEGORY):
  return CATEGORY.upper()

# %%
#temp

#for permanency it should be assigned
df['CATEGORY'].apply(update_case)
# Out:
# 0      APPARELS
# 1      APPARELS
# 2      APPARELS
# 3      APPARELS
# 4      APPARELS
#          ...
# 137    APPARELS
# 138    APPARELS
# 139    APPARELS
# 140    APPARELS
# 141    APPARELS
# Name: CATEGORY, Length: 142, dtype: object

# %%
###if apply ran on column it returns series, if on series ----> series

df['CATEGORY'] = df['CATEGORY'].apply(update_case)

df
# Out:
#      ORDERID  ORDERDATE   SHIPDATE      SHIPMODE  CUSTOMERID  CATEGORY  \
# 0         10  3/14/2023  3/23/2023   FIRST CLASS         220  APPARELS
# 1         16  3/14/2023  3/22/2023  SECOND CLASS         325  APPARELS
# 2         21  3/14/2023  3/20/2023   FIRST CLASS         245  APPARELS
# 3         23  3/14/2023  3/20/2023   FIRST CLASS         158  APPARELS
# 4         36  3/14/2023  3/20/2023      STANDARD         364  APPARELS
# ..       ...        ...        ...           ...         ...       ...
# 137      129  3/14/2023  3/23/2023   FIRST CLASS         218  APPARELS
# 138      145  3/14/2023  3/21/2023   FIRST CLASS         361  APPARELS
# 139      157  3/14/2023  3/20/2023   FIRST CLASS         138  APPARELS
# 140      160  3/14/2023  3/20/2023      STANDARD         386  APPARELS
# 141      167  3/14/2023  3/23/2023  SECOND CLASS         163  APPARELS
#
#     CITYNAMES COUNTRYNAMES  POSTALCODE         ITEM  QUANTITY  COST  TOTAL  \
# ...

# %%
df['CITYNAMES'] = df['CITYNAMES'].apply(lambda x: x.lower())

df
# Out:
#      ORDERID  ORDERDATE   SHIPDATE      SHIPMODE  CUSTOMERID  CATEGORY  \
# 0         10  3/14/2023  3/23/2023   FIRST CLASS         220  APPARELS
# 1         16  3/14/2023  3/22/2023  SECOND CLASS         325  APPARELS
# 2         21  3/14/2023  3/20/2023   FIRST CLASS         245  APPARELS
# 3         23  3/14/2023  3/20/2023   FIRST CLASS         158  APPARELS
# 4         36  3/14/2023  3/20/2023      STANDARD         364  APPARELS
# ..       ...        ...        ...           ...         ...       ...
# 137      129  3/14/2023  3/23/2023   FIRST CLASS         218  APPARELS
# 138      145  3/14/2023  3/21/2023   FIRST CLASS         361  APPARELS
# 139      157  3/14/2023  3/20/2023   FIRST CLASS         138  APPARELS
# 140      160  3/14/2023  3/20/2023      STANDARD         386  APPARELS
# 141      167  3/14/2023  3/23/2023  SECOND CLASS         163  APPARELS
#
#     CITYNAMES COUNTRYNAMES  POSTALCODE         ITEM  QUANTITY  COST  TOTAL  \
# ...

# %%
##apply ----> on dataframes
#######--------------applies to values of series, i.e. columns' values, of the dataframe
#by default it calculates based on columns --->vertical cal
#df['ITEM'].apply(len)        ------        will give length of every column entry

# %%
df.apply(len)
# Out:
# ORDERID         142
# ORDERDATE       142
# SHIPDATE        142
# SHIPMODE        142
# CUSTOMERID      142
# CATEGORY        142
# CITYNAMES       142
# COUNTRYNAMES    142
# POSTALCODE      142
# ITEM            142
# QUANTITY        142
# COST            142
# TOTAL           142
# PROFIT          142
# dtype: int64

# %%
df.apply(len, axis='columns')
# Out:
# 0      14
# 1      14
# 2      14
# 3      14
# 4      14
#        ..
# 137    14
# 138    14
# 139    14
# 140    14
# 141    14
# Length: 142, dtype: int64

# %%
len(df['ITEM'])     #gives number of rows
# Out:
# 142

# %%
df.apply(pd.Series.min)
# Out:
# ORDERID                   3
# ORDERDATE         3/14/2023
# SHIPDATE          3/19/2023
# SHIPMODE        FIRST CLASS
# CUSTOMERID              101
# CATEGORY           APPARELS
# CITYNAMES              agra
# COUNTRYNAMES          INDIA
# POSTALCODE           110001
# ITEM            ACTIVE-WEAR
# QUANTITY                  1
# COST                    106
# TOTAL                   108
# PROFIT                    0
# dtype: object

# %%
df.apply(lambda x: x.min())
# Out:
# ORDERID                   3
# ORDERDATE         3/14/2023
# SHIPDATE          3/19/2023
# SHIPMODE        FIRST CLASS
# CUSTOMERID              101
# CATEGORY           APPARELS
# CITYNAMES              agra
# COUNTRYNAMES          INDIA
# POSTALCODE           110001
# ITEM            ACTIVE-WEAR
# QUANTITY                  1
# COST                    106
# TOTAL                   108
# PROFIT                    0
# dtype: object

# %%
#######apply values to every individual element

# %%
#df.applymap(len)

# %%
df.applymap(str.lower)

#since we have integer columns , if we had all string columns it would have worked
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-05651c37aec8> in <cell line: 1>()
# ----> 1 df.applymap(str.lower)
#       2
#       3 #since we have integer columns , if we had all string columns it would have worked
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py in applymap(self, func, na_action, **kwargs)
#    9651             return lib.map_infer(x.astype(object)._values, func, ignore_na=ignore_na)
#    9652
# -> 9653         return self.apply(infer).__finalize__(self, "applymap")
#    9654
#    9655     # ----------------------------------------------------------------------
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    9566             kwargs=kwargs,
#    9567         )
# -> 9568         return op.apply().__finalize__(self, method="apply")
#    9569
# ...

# %%
###########map method ----> works on series object

#update, replace values

# %%
df
# Out:
#      ORDERID  ORDERDATE   SHIPDATE      SHIPMODE  CUSTOMERID  CATEGORY  \
# 0         10  3/14/2023  3/23/2023   FIRST CLASS         220  APPARELS
# 1         16  3/14/2023  3/22/2023  SECOND CLASS         325  APPARELS
# 2         21  3/14/2023  3/20/2023   FIRST CLASS         245  APPARELS
# 3         23  3/14/2023  3/20/2023   FIRST CLASS         158  APPARELS
# 4         36  3/14/2023  3/20/2023      STANDARD         364  APPARELS
# ..       ...        ...        ...           ...         ...       ...
# 137      129  3/14/2023  3/23/2023   FIRST CLASS         218  APPARELS
# 138      145  3/14/2023  3/21/2023   FIRST CLASS         361  APPARELS
# 139      157  3/14/2023  3/20/2023   FIRST CLASS         138  APPARELS
# 140      160  3/14/2023  3/20/2023      STANDARD         386  APPARELS
# 141      167  3/14/2023  3/23/2023  SECOND CLASS         163  APPARELS
#
#     CITYNAMES COUNTRYNAMES  POSTALCODE         ITEM  QUANTITY  COST  TOTAL  \
# ...

# %%
df['ITEM'].map({'SHERWANIS': 'LEHENGA', 'COATS': 'DENIM TRUCKER'})
# Out:
# 0            LEHENGA
# 1      DENIM TRUCKER
# 2                NaN
# 3                NaN
# 4                NaN
#            ...
# 137              NaN
# 138              NaN
# 139              NaN
# 140              NaN
# 141              NaN
# Name: ITEM, Length: 142, dtype: object

# %%
df['ITEM'].replace({'SHERWANIS': 'LEHENGA', 'COATS': 'DENIM TRUCKER'})
# Out:
# 0            LEHENGA
# 1      DENIM TRUCKER
# 2            NOODLES
# 3              SHIRT
# 4           SNEAKERS
#            ...
# 137      TABLE LAMPS
# 138            HEELS
# 139            SHIRT
# 140             MILK
# 141         PLANTERS
# Name: ITEM, Length: 142, dtype: object

# %%
df
# Out:
#      ORDERID  ORDERDATE   SHIPDATE      SHIPMODE  CUSTOMERID  CATEGORY  \
# 0         10  3/14/2023  3/23/2023   FIRST CLASS         220  APPARELS
# 1         16  3/14/2023  3/22/2023  SECOND CLASS         325  APPARELS
# 2         21  3/14/2023  3/20/2023   FIRST CLASS         245  APPARELS
# 3         23  3/14/2023  3/20/2023   FIRST CLASS         158  APPARELS
# 4         36  3/14/2023  3/20/2023      STANDARD         364  APPARELS
# ..       ...        ...        ...           ...         ...       ...
# 137      129  3/14/2023  3/23/2023   FIRST CLASS         218  APPARELS
# 138      145  3/14/2023  3/21/2023   FIRST CLASS         361  APPARELS
# 139      157  3/14/2023  3/20/2023   FIRST CLASS         138  APPARELS
# 140      160  3/14/2023  3/20/2023      STANDARD         386  APPARELS
# 141      167  3/14/2023  3/23/2023  SECOND CLASS         163  APPARELS
#
#     CITYNAMES COUNTRYNAMES  POSTALCODE         ITEM  QUANTITY  COST  TOTAL  \
# ...

# %%
df['ITEM'] = df['ITEM'].replace({'SHERWANIS': 'LEHENGA', 'COATS': 'DENIM TRUCKER'})

# %%
df
# Out:
#      ORDERID  ORDERDATE   SHIPDATE      SHIPMODE  CUSTOMERID  CATEGORY  \
# 0         10  3/14/2023  3/23/2023   FIRST CLASS         220  APPARELS
# 1         16  3/14/2023  3/22/2023  SECOND CLASS         325  APPARELS
# 2         21  3/14/2023  3/20/2023   FIRST CLASS         245  APPARELS
# 3         23  3/14/2023  3/20/2023   FIRST CLASS         158  APPARELS
# 4         36  3/14/2023  3/20/2023      STANDARD         364  APPARELS
# ..       ...        ...        ...           ...         ...       ...
# 137      129  3/14/2023  3/23/2023   FIRST CLASS         218  APPARELS
# 138      145  3/14/2023  3/21/2023   FIRST CLASS         361  APPARELS
# 139      157  3/14/2023  3/20/2023   FIRST CLASS         138  APPARELS
# 140      160  3/14/2023  3/20/2023      STANDARD         386  APPARELS
# 141      167  3/14/2023  3/23/2023  SECOND CLASS         163  APPARELS
#
#     CITYNAMES COUNTRYNAMES  POSTALCODE           ITEM  QUANTITY  COST  TOTAL  \
# ...

# %%
df['CITYNAMES'] = df['CITYNAMES'].str.upper()

# %%
df
# Out:
#      ORDERID  ORDERDATE   SHIPDATE      SHIPMODE  CUSTOMERID  CATEGORY  \
# 0         10  3/14/2023  3/23/2023   FIRST CLASS         220  APPARELS
# 1         16  3/14/2023  3/22/2023  SECOND CLASS         325  APPARELS
# 2         21  3/14/2023  3/20/2023   FIRST CLASS         245  APPARELS
# 3         23  3/14/2023  3/20/2023   FIRST CLASS         158  APPARELS
# 4         36  3/14/2023  3/20/2023      STANDARD         364  APPARELS
# ..       ...        ...        ...           ...         ...       ...
# 137      129  3/14/2023  3/23/2023   FIRST CLASS         218  APPARELS
# 138      145  3/14/2023  3/21/2023   FIRST CLASS         361  APPARELS
# 139      157  3/14/2023  3/20/2023   FIRST CLASS         138  APPARELS
# 140      160  3/14/2023  3/20/2023      STANDARD         386  APPARELS
# 141      167  3/14/2023  3/23/2023  SECOND CLASS         163  APPARELS
#
#     CITYNAMES COUNTRYNAMES  POSTALCODE           ITEM  QUANTITY  COST  TOTAL  \
# ...

# %%
df.rename(columns={'COUNTRYNAMES': 'COUNTRY'}, inplace=True)

# %%
df
# Out:
#      ORDERID  ORDERDATE   SHIPDATE      SHIPMODE  CUSTOMERID  CATEGORY  \
# 0         10  3/14/2023  3/23/2023   FIRST CLASS         220  APPARELS
# 1         16  3/14/2023  3/22/2023  SECOND CLASS         325  APPARELS
# 2         21  3/14/2023  3/20/2023   FIRST CLASS         245  APPARELS
# 3         23  3/14/2023  3/20/2023   FIRST CLASS         158  APPARELS
# 4         36  3/14/2023  3/20/2023      STANDARD         364  APPARELS
# ..       ...        ...        ...           ...         ...       ...
# 137      129  3/14/2023  3/23/2023   FIRST CLASS         218  APPARELS
# 138      145  3/14/2023  3/21/2023   FIRST CLASS         361  APPARELS
# 139      157  3/14/2023  3/20/2023   FIRST CLASS         138  APPARELS
# 140      160  3/14/2023  3/20/2023      STANDARD         386  APPARELS
# 141      167  3/14/2023  3/23/2023  SECOND CLASS         163  APPARELS
#
#     CITYNAMES COUNTRY  POSTALCODE           ITEM  QUANTITY  COST  TOTAL  \
# ...

# %%
df[''] = df[''].map({'Yes': True, 'No': False})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
################ --- Add / Remove Rows & Columns from DataFrames

# %%
people = {
    'first':  ['Corey', 'Jane', 'John'],
    'last': ['Schafer', 'Doe', 'Doe'],
    'email':  ['CoreySchafer@gmail.com', 'JaneDoe@gmail.com', 'JohnDoe@gmail.com']
}

# %%
df1 = pd.DataFrame(people)

# %%
df1
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 1   Jane      Doe       JaneDoe@gmail.com
# 2   John      Doe       JohnDoe@gmail.com

# %%
df1['first'] + ' ' + df1['last']
# Out:
# 0    Corey Schafer
# 1         Jane Doe
# 2         John Doe
# dtype: object

# %%
###add new column
df1['full_name'] = df1['first'] + ' ' + df1['last']

# %%
df1
# Out:
#    first     last                   email      full_name
# 0  Corey  Schafer  CoreySchafer@gmail.com  Corey Schafer
# 1   Jane      Doe       JaneDoe@gmail.com       Jane Doe
# 2   John      Doe       JohnDoe@gmail.com       John Doe

# %%
df1.drop(columns=['first', 'last'], inplace=True)

# %%
df1
# Out:
#                     email      full_name
# 0  CoreySchafer@gmail.com  Corey Schafer
# 1       JaneDoe@gmail.com       Jane Doe
# 2       JohnDoe@gmail.com       John Doe

# %%
df1['full_name'].str.split(' ', expand=True)
# Out:
#        0        1
# 0  Corey  Schafer
# 1   Jane      Doe
# 2   John      Doe

# %%
df1[['first', 'last']] = df1['full_name'].str.split(' ', expand=True)

# %%
df1
# Out:
#                     email      full_name  first     last
# 0  CoreySchafer@gmail.com  Corey Schafer  Corey  Schafer
# 1       JaneDoe@gmail.com       Jane Doe   Jane      Doe
# 2       JohnDoe@gmail.com       John Doe   John      Doe

# %%
df.append({'first': 'Deeksha'})
# Out:
# <ipython-input-110-32ec03ec3787>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append({'first': 'Deeksha'})
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-110-32ec03ec3787> in <cell line: 1>()
# ----> 1 df.append({'first': 'Deeksha'})
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    9766         )
#    9767
# -> 9768         return self._append(other, ignore_index, verify_integrity, sort)
#    9769
#    9770     def _append(
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py in _append(self, other, ignore_index, verify_integrity, sort)
#    9778             if isinstance(other, dict):
#    9779                 if not ignore_index:
# ...

# %%
df.append({'first': 'Deeksha'}, ignore_index=True)
# Out:
# <ipython-input-112-42f748c939af>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append({'first': 'Deeksha'}, ignore_index=True)
#      ORDERID  ORDERDATE   SHIPDATE      SHIPMODE  CUSTOMERID  CATEGORY  \
# 0       10.0  3/14/2023  3/23/2023   FIRST CLASS       220.0  APPARELS
# 1       16.0  3/14/2023  3/22/2023  SECOND CLASS       325.0  APPARELS
# 2       21.0  3/14/2023  3/20/2023   FIRST CLASS       245.0  APPARELS
# 3       23.0  3/14/2023  3/20/2023   FIRST CLASS       158.0  APPARELS
# 4       36.0  3/14/2023  3/20/2023      STANDARD       364.0  APPARELS
# ..       ...        ...        ...           ...         ...       ...
# 138    145.0  3/14/2023  3/21/2023   FIRST CLASS       361.0  APPARELS
# 139    157.0  3/14/2023  3/20/2023   FIRST CLASS       138.0  APPARELS
# 140    160.0  3/14/2023  3/20/2023      STANDARD       386.0  APPARELS
# ...

# %%
people = {
    'first':  ['Moksh', 'Manisha'],
    'last': ['Patidar', 'Patidar'],
    'email':  ['MokshPatidar@gmail.com', 'ManishaPatidar@gmail.com']
}

df2 = pd.DataFrame(people)

# %%
df2
# Out:
#      first     last                     email
# 0    Moksh  Patidar    MokshPatidar@gmail.com
# 1  Manisha  Patidar  ManishaPatidar@gmail.com

# %%
df1.append(df2, ignore_index=True, sort=False)
# Out:
# <ipython-input-115-eb86f9cbf927>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1.append(df2, ignore_index=True, sort=False)
#                       email      full_name    first     last
# 0    CoreySchafer@gmail.com  Corey Schafer    Corey  Schafer
# 1         JaneDoe@gmail.com       Jane Doe     Jane      Doe
# 2         JohnDoe@gmail.com       John Doe     John      Doe
# 3    MokshPatidar@gmail.com            NaN    Moksh  Patidar
# 4  ManishaPatidar@gmail.com            NaN  Manisha  Patidar

# %%
df1 = df1.append(df2, ignore_index=True, sort=False)
# Out:
# <ipython-input-116-22d6c04e0e94>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1 = df1.append(df2, ignore_index=True, sort=False)

# %%
df1
# Out:
#                       email      full_name    first     last
# 0    CoreySchafer@gmail.com  Corey Schafer    Corey  Schafer
# 1         JaneDoe@gmail.com       Jane Doe     Jane      Doe
# 2         JohnDoe@gmail.com       John Doe     John      Doe
# 3    MokshPatidar@gmail.com            NaN    Moksh  Patidar
# 4  ManishaPatidar@gmail.com            NaN  Manisha  Patidar

# %%
df1.drop(index=4)
# Out:
#                     email      full_name  first     last
# 0  CoreySchafer@gmail.com  Corey Schafer  Corey  Schafer
# 1       JaneDoe@gmail.com       Jane Doe   Jane      Doe
# 2       JohnDoe@gmail.com       John Doe   John      Doe
# 3  MokshPatidar@gmail.com            NaN  Moksh  Patidar

# %%
df1.drop(index=df1[df1['last'] == 'Doe'].index)
# Out:
#                       email      full_name    first     last
# 0    CoreySchafer@gmail.com  Corey Schafer    Corey  Schafer
# 3    MokshPatidar@gmail.com            NaN    Moksh  Patidar
# 4  ManishaPatidar@gmail.com            NaN  Manisha  Patidar

# %%
######################### SORT DATA ##############################################

# %%
df1.sort_values(by='last', ascending=False)
# Out:
#                       email      full_name    first     last
# 0    CoreySchafer@gmail.com  Corey Schafer    Corey  Schafer
# 3    MokshPatidar@gmail.com            NaN    Moksh  Patidar
# 4  ManishaPatidar@gmail.com            NaN  Manisha  Patidar
# 1         JaneDoe@gmail.com       Jane Doe     Jane      Doe
# 2         JohnDoe@gmail.com       John Doe     John      Doe

# %%
df1.sort_values(by='last')
# Out:
#                       email      full_name    first     last
# 1         JaneDoe@gmail.com       Jane Doe     Jane      Doe
# 2         JohnDoe@gmail.com       John Doe     John      Doe
# 3    MokshPatidar@gmail.com            NaN    Moksh  Patidar
# 4  ManishaPatidar@gmail.com            NaN  Manisha  Patidar
# 0    CoreySchafer@gmail.com  Corey Schafer    Corey  Schafer

# %%
df1.sort_values(by=['last', 'first'], ascending=False)
# Out:
#                       email      full_name    first     last
# 0    CoreySchafer@gmail.com  Corey Schafer    Corey  Schafer
# 3    MokshPatidar@gmail.com            NaN    Moksh  Patidar
# 4  ManishaPatidar@gmail.com            NaN  Manisha  Patidar
# 2         JohnDoe@gmail.com       John Doe     John      Doe
# 1         JaneDoe@gmail.com       Jane Doe     Jane      Doe

# %%
df1 = df1.append({'email': 'DeekshaPatidar@gmail.com', 'full_name': 'Deeksha Patidar', 'first': 'Deeksha', 'last': 'Patidar'}, ignore_index=True)
# Out:
# <ipython-input-124-fa865309163b>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1 = df1.append({'email': 'DeekshaPatidar@gmail.com', 'full_name': 'Deeksha Patidar', 'first': 'Deeksha', 'last': 'Patidar'}, ignore_index=True)

# %%
df1
# Out:
#                       email        full_name    first     last
# 0    CoreySchafer@gmail.com    Corey Schafer    Corey  Schafer
# 1         JaneDoe@gmail.com         Jane Doe     Jane      Doe
# 2         JohnDoe@gmail.com         John Doe     John      Doe
# 3    MokshPatidar@gmail.com              NaN    Moksh  Patidar
# 4  ManishaPatidar@gmail.com              NaN  Manisha  Patidar
# 5  DeekshaPatidar@gmail.com  Deeksha Patidar  Deeksha  Patidar

# %%
df1.sort_values(by=['last', 'first'], ascending=[False, True])

#### df1.sort_values(by=['last', 'first'], ascending=[False, True], inplace =True)
# Out:
#                       email        full_name    first     last
# 0    CoreySchafer@gmail.com    Corey Schafer    Corey  Schafer
# 5  DeekshaPatidar@gmail.com  Deeksha Patidar  Deeksha  Patidar
# 4  ManishaPatidar@gmail.com              NaN  Manisha  Patidar
# 3    MokshPatidar@gmail.com              NaN    Moksh  Patidar
# 1         JaneDoe@gmail.com         Jane Doe     Jane      Doe
# 2         JohnDoe@gmail.com         John Doe     John      Doe

# %%
df1.sort_index()
# Out:
#                       email        full_name    first     last
# 0    CoreySchafer@gmail.com    Corey Schafer    Corey  Schafer
# 1         JaneDoe@gmail.com         Jane Doe     Jane      Doe
# 2         JohnDoe@gmail.com         John Doe     John      Doe
# 3    MokshPatidar@gmail.com              NaN    Moksh  Patidar
# 4  ManishaPatidar@gmail.com              NaN  Manisha  Patidar
# 5  DeekshaPatidar@gmail.com  Deeksha Patidar  Deeksha  Patidar

# %%
df1['last'].sort_values()
# Out:
# 1        Doe
# 2        Doe
# 3    Patidar
# 4    Patidar
# 5    Patidar
# 0    Schafer
# Name: last, dtype: object

# %%
df
# Out:
#      ORDERID  ORDERDATE   SHIPDATE      SHIPMODE  CUSTOMERID  CATEGORY  \
# 0         10  3/14/2023  3/23/2023   FIRST CLASS         220  APPARELS
# 1         16  3/14/2023  3/22/2023  SECOND CLASS         325  APPARELS
# 2         21  3/14/2023  3/20/2023   FIRST CLASS         245  APPARELS
# 3         23  3/14/2023  3/20/2023   FIRST CLASS         158  APPARELS
# 4         36  3/14/2023  3/20/2023      STANDARD         364  APPARELS
# ..       ...        ...        ...           ...         ...       ...
# 137      129  3/14/2023  3/23/2023   FIRST CLASS         218  APPARELS
# 138      145  3/14/2023  3/21/2023   FIRST CLASS         361  APPARELS
# 139      157  3/14/2023  3/20/2023   FIRST CLASS         138  APPARELS
# 140      160  3/14/2023  3/20/2023      STANDARD         386  APPARELS
# 141      167  3/14/2023  3/23/2023  SECOND CLASS         163  APPARELS
#
#     CITYNAMES COUNTRY  POSTALCODE           ITEM  QUANTITY  COST  TOTAL  \
# ...

# %%
df.sort_values(by='PROFIT',ascending = False, inplace=True)

df['PROFIT'].head(25)
# Out:
# 4      567
# 25     490
# 101    478
# 90     408
# 39     332
# 11     324
# 68     310
# 51     294
# 103    286
# 139    285
# 107    271
# 12     271
# 57     264
# 119    260
# 33     252
# 115    251
# 95     242
# 44     242
# 63     240
# 78     233
# 112    222
# 120    221
# 42     219
# 64     212
# 52     211
# Name: PROFIT, dtype: int64

# %%
df[['ITEM', 'PROFIT']].head(25)
# Out:
#                      ITEM  PROFIT
# 4                SNEAKERS     567
# 25         LEHENGA CHOLIS     490
# 101                 FLATS     478
# 90                MIRRORS     408
# 39            SWEATSHIRTS     332
# 11                  VASES     324
# 68                  RAJMA     310
# 51                  RAJMA     294
# 103                  MILK     286
# 139                 SHIRT     285
# 107               COOKIES     271
# 12            TABLE LAMPS     271
# 57   BATHROOM ACCESSORIES     264
# 119               NUTELLA     260
# 33               TROUSERS     252
# 115            GLADIATORS     251
# 95            SKATE SHOES     242
# 44                NOODLES     242
# 63                DORITOS     240
# 78                 SHRUGS     233
# 112              FOOD OIL     222
# 120        SPORTS SANDALS     221
# 42                  SOCKS     219
# 64   BATHROOM ACCESSORIES     212
# 52             RAIN BOOTS     211

# %%
df.sort_values(by=['PROFIT', 'ITEM'],ascending = [True, False], inplace=True)

# %%
df['PROFIT'].nlargest(15)
# Out:
# 4      567
# 25     490
# 101    478
# 90     408
# 39     332
# 11     324
# 68     310
# 51     294
# 103    286
# 139    285
# 12     271
# 107    271
# 57     264
# 119    260
# 33     252
# Name: PROFIT, dtype: int64

# %%
df.nlargest(15, 'PROFIT')
# Out:
#      ORDERID  ORDERDATE   SHIPDATE      SHIPMODE  CUSTOMERID  CATEGORY  \
# 4         36  3/14/2023  3/20/2023      STANDARD         364  APPARELS
# 25        21  3/14/2023  3/20/2023   FIRST CLASS         250  APPARELS
# 101       51  3/14/2023  3/24/2023  SECOND CLASS         182  APPARELS
# 90       161  3/14/2023  3/21/2023  SECOND CLASS         146  APPARELS
# 39       112  3/14/2023  3/20/2023      STANDARD         302  APPARELS
# 11        96  3/14/2023  3/19/2023  SECOND CLASS         353  APPARELS
# 68       119  3/14/2023  3/22/2023   FIRST CLASS         136  APPARELS
# 51       178  3/14/2023  3/20/2023   FIRST CLASS         174  APPARELS
# 103       60  3/14/2023  3/24/2023  SECOND CLASS         163  APPARELS
# 139      157  3/14/2023  3/20/2023   FIRST CLASS         138  APPARELS
# 12        99  3/14/2023  3/19/2023      STANDARD         192  APPARELS
# 107      120  3/14/2023  3/23/2023      STANDARD         140  APPARELS
# ...

# %%
############### GROUPING & AGGREGATING ######################

# %%
df['PROFIT'].median()
# Out:
# 70.5

# %%
df.median()
# Out:
# <ipython-input-137-6d467abf240d>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# ORDERID           92.0
# CUSTOMERID       238.5
# POSTALCODE    307501.0
# QUANTITY           5.0
# COST             521.5
# TOTAL           2227.5
# PROFIT            70.5
# dtype: float64

# %%
df.describe()
# Out:
#           ORDERID  CUSTOMERID     POSTALCODE    QUANTITY         COST  \
# count  142.000000  142.000000     142.000000  142.000000   142.000000
# mean    93.887324  244.091549  306321.781690    5.584507   525.619718
# std     53.221749   84.433524  156841.753772    2.858961   280.060397
# min      3.000000  101.000000  110001.000000    1.000000   106.000000
# 25%     49.500000  170.250000  194201.000000    3.000000   297.000000
# 50%     92.000000  238.500000  307501.000000    5.000000   521.500000
# 75%    133.750000  315.250000  400008.000000    8.000000   726.250000
# max    197.000000  398.000000  584101.000000   10.000000  1697.000000
#
#              TOTAL      PROFIT
# count   142.000000  142.000000
# mean   2776.633803  107.021127
# std    2078.800880  109.066410
# min     108.000000    0.000000
# 25%    1188.250000   25.250000
# 50%    2227.500000   70.500000
# 75%    3881.250000  164.750000
# max    8910.000000  567.000000

# %%
df['PROFIT'].count()
# Out:
# 142

# %%
df['CITYNAMES'].value_counts()
# Out:
# MUMBAI        47
# KANPUR        11
# CHENNAI        8
# INDORE         8
# JAIPUR         7
# AGRA           7
# BANGLORE       7
# GUWAHATI       6
# NOIDA          6
# GUJARAT        6
# KERALA         6
# SIKKIM         6
# PUNE           5
# HYDERABAD      5
# DELHI          4
# CHANDIGARH     3
# Name: CITYNAMES, dtype: int64

# %%
df['ITEM']
# Out:
# 100       TABLE LAMPS
# 104    SPORTS SANDALS
# 72        SOFA COVERS
# 3               SHIRT
# 8             SANDALS
#             ...
# 39        SWEATSHIRTS
# 90            MIRRORS
# 101             FLATS
# 25     LEHENGA CHOLIS
# 4            SNEAKERS
# Name: ITEM, Length: 142, dtype: object

# %%
df['ITEM'].value_counts()
# Out:
# TABLE LAMPS    6
# SOFA COVERS    4
# PULSES         4
# GLADIATORS     4
# CHESSE         4
#               ..
# BREAD          1
# BAKERWARE      1
# QUILTS         1
# PLANTERS       1
# SKATE SHOES    1
# Name: ITEM, Length: 68, dtype: int64

# %%
df['ITEM'].value_counts(normalize=True)
# Out:
# TABLE LAMPS    0.042254
# SOFA COVERS    0.028169
# PULSES         0.028169
# GLADIATORS     0.028169
# CHESSE         0.028169
#                  ...
# BREAD          0.007042
# BAKERWARE      0.007042
# QUILTS         0.007042
# PLANTERS       0.007042
# SKATE SHOES    0.007042
# Name: ITEM, Length: 68, dtype: float64

# %%
###################### GROUP BY ####################### --------- Split, Apply, Combine

# %%
item_grp = df.groupby(['ITEM'])

# %%
for item, item_df in item_grp:
  print(item)
  print(item_df)
# Out:
# <ipython-input-267-6dd08f8b888c>:1: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for item, item_df in item_grp:
# ACTIVE-WEAR
#      ORDERID  ORDERDATE   SHIPDATE     SHIPMODE  CUSTOMERID  CATEGORY  \
# 34        74  3/14/2023  3/24/2023  FIRST CLASS         237  APPARELS
# 114      189  3/14/2023  3/21/2023  FIRST CLASS         170  APPARELS
#
#     CITYNAMES COUNTRY  POSTALCODE         ITEM  QUANTITY  COST  TOTAL  PROFIT
# 34    GUJARAT   INDIA      307501  ACTIVE-WEAR         2   626   1252      37
# 114      AGRA   INDIA      307501  ACTIVE-WEAR         5   302   1510     135
# AROMAS AND CANDLES
#      ORDERID  ORDERDATE   SHIPDATE     SHIPMODE  CUSTOMERID  CATEGORY  \
# 22       186  3/14/2023  3/24/2023  FIRST CLASS         136  APPARELS
# ...

# %%
# item_grp.max()

# item_grp.mean()

item_grp.describe()
# Out:
#                      ORDERID                                               \
#                        count        mean        std    min     25%    50%
# ITEM
# ACTIVE-WEAR              2.0  131.500000  81.317280   74.0  102.75  131.5
# AROMAS AND CANDLES       2.0  142.000000  62.225397   98.0  120.00  142.0
# BAKERWARE                1.0   41.000000        NaN   41.0   41.00   41.0
# BATHROOM ACCESSORIES     3.0   51.000000  37.242449    8.0   40.00   72.0
# BLANKETS                 3.0  102.000000  48.569538   55.0   77.00   99.0
# ...                      ...         ...        ...    ...     ...    ...
# TABLE LAMPS              6.0   91.666667  39.312424   39.0   60.75  102.5
# TOPS                     2.0  179.500000  20.506097  165.0  172.25  179.5
# TROUSERS                 2.0   91.000000  28.284271   71.0   81.00   91.0
# VASES                    2.0  108.000000  16.970563   96.0  102.00  108.0
# WALL DECOR               1.0   84.000000        NaN   84.0   84.00   84.0
#
# ...

# %%
# %matplotlib inline
item_grp.plot()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
item_grp.get_group('TABLE LAMPS')
# Out:
#      ORDERID  ORDERDATE   SHIPDATE     SHIPMODE  CUSTOMERID  CATEGORY  \
# 100       48  3/14/2023  3/23/2023     STANDARD         234  APPARELS
# 67       106  3/14/2023  3/19/2023  FIRST CLASS         252  APPARELS
# 98        39  3/14/2023  3/24/2023     STANDARD         321  APPARELS
# 43       129  3/14/2023  3/24/2023  FIRST CLASS         200  APPARELS
# 137      129  3/14/2023  3/23/2023  FIRST CLASS         218  APPARELS
# 12        99  3/14/2023  3/19/2023     STANDARD         192  APPARELS
#
#     CITYNAMES COUNTRY  POSTALCODE         ITEM  QUANTITY  COST  TOTAL  PROFIT
# 100    MUMBAI   INDIA      563130  TABLE LAMPS         3   632   1896       0
# 67      DELHI   INDIA      560064  TABLE LAMPS         2   303    606      12
# 98     MUMBAI   INDIA      307501  TABLE LAMPS         3   348   1044      93
# 43     KERALA   INDIA      560064  TABLE LAMPS         3   569   1707     119
# 137   CHENNAI   INDIA      307501  TABLE LAMPS         9   390   3510     175
# ...

# %%
item_grp.get_group('QUILTS')
# Out:
#      ORDERID  ORDERDATE   SHIPDATE  SHIPMODE  CUSTOMERID  CATEGORY CITYNAMES  \
# 105       85  3/14/2023  3/23/2023  STANDARD         253  APPARELS    MUMBAI
#
#     COUNTRY  POSTALCODE    ITEM  QUANTITY  COST  TOTAL  PROFIT
# 105   INDIA      110020  QUILTS        10   223   2230      22

# %%
filterG1 = df['ITEM'] == 'TABLE LAMPS'
df.loc[filterG1]
# Out:
#      ORDERID  ORDERDATE   SHIPDATE     SHIPMODE  CUSTOMERID  CATEGORY  \
# 100       48  3/14/2023  3/23/2023     STANDARD         234  APPARELS
# 67       106  3/14/2023  3/19/2023  FIRST CLASS         252  APPARELS
# 98        39  3/14/2023  3/24/2023     STANDARD         321  APPARELS
# 43       129  3/14/2023  3/24/2023  FIRST CLASS         200  APPARELS
# 137      129  3/14/2023  3/23/2023  FIRST CLASS         218  APPARELS
# 12        99  3/14/2023  3/19/2023     STANDARD         192  APPARELS
#
#     CITYNAMES COUNTRY  POSTALCODE         ITEM  QUANTITY  COST  TOTAL  PROFIT
# 100    MUMBAI   INDIA      563130  TABLE LAMPS         3   632   1896       0
# 67      DELHI   INDIA      560064  TABLE LAMPS         2   303    606      12
# 98     MUMBAI   INDIA      307501  TABLE LAMPS         3   348   1044      93
# 43     KERALA   INDIA      560064  TABLE LAMPS         3   569   1707     119
# 137   CHENNAI   INDIA      307501  TABLE LAMPS         9   390   3510     175
# ...

# %%
df.loc[filterG1]['CITYNAMES'].value_counts()
# Out:
# MUMBAI     3
# DELHI      1
# KERALA     1
# CHENNAI    1
# Name: CITYNAMES, dtype: int64

# %%
item_grp['CITYNAMES'].value_counts().head(50)
# Out:
# ITEM                  CITYNAMES
# ACTIVE-WEAR           AGRA          1
#                       GUJARAT       1
# AROMAS AND CANDLES    BANGLORE      1
#                       INDORE        1
# BAKERWARE             AGRA          1
# BATHROOM ACCESSORIES  MUMBAI        2
#                       KANPUR        1
# BLANKETS              CHANDIGARH    1
#                       MUMBAI        1
#                       SIKKIM        1
# BLAZERS               CHENNAI       1
#                       GUJARAT       1
# BOOTS                 GUWAHATI      1
#                       NOIDA         1
# BREAD                 MUMBAI        1
# BUTTER                DELHI         1
#                       KERALA        1
#                       MUMBAI        1
# CARPETS               GUJARAT       1
# CASUAL SHOES          NOIDA         1
# CHELSEA BOOTS         KANPUR        1
#                       SIKKIM        1
# CHESSE                HYDERABAD     2
#                       AGRA          1
# ...

# %%
item_grp['CITYNAMES'].value_counts().loc['CHESSE']
# Out:
# CITYNAMES
# HYDERABAD    2
# AGRA         1
# MUMBAI       1
# Name: CITYNAMES, dtype: int64

# %%
item_grp['CITYNAMES'].value_counts(normalize=True).loc['CHESSE']
# Out:
# CITYNAMES
# HYDERABAD    0.50
# AGRA         0.25
# MUMBAI       0.25
# Name: CITYNAMES, dtype: float64

# %%
###country_grp[''].median().loc['']

# %%
item_grp['COST'].agg(['median', 'mean'])
# Out:
#                       median        mean
# ITEM
# ACTIVE-WEAR            464.0  464.000000
# AROMAS AND CANDLES     538.5  538.500000
# BAKERWARE              812.0  812.000000
# BATHROOM ACCESSORIES   367.0  419.333333
# BLANKETS               297.0  415.000000
# ...                      ...         ...
# TABLE LAMPS            479.5  486.833333
# TOPS                   202.0  202.000000
# TROUSERS               527.5  527.500000
# VASES                  820.5  820.500000
# WALL DECOR             456.0  456.000000
#
# [68 rows x 2 columns]

# %%
item_grp['COST'].agg(['median', 'mean']).loc['VASES']
# Out:
# median    820.5
# mean      820.5
# Name: VASES, dtype: float64

# %%
#### filter = (df['CITYNAMES'] == 'MUMBAI')
#### df.loc[filter][''].str.contains('').sum()

#### country_grp[''].str.contains('').sum()

# %%
city_name_mumbai = item_grp['CITYNAMES'].apply(lambda x: x.str.contains('MUMBAI').sum())

# %%
city_count = df['CITYNAMES'].value_counts()
city_count
# Out:
# MUMBAI        47
# KANPUR        11
# CHENNAI        8
# INDORE         8
# JAIPUR         7
# AGRA           7
# BANGLORE       7
# GUWAHATI       6
# NOIDA          6
# GUJARAT        6
# KERALA         6
# SIKKIM         6
# PUNE           5
# HYDERABAD      5
# DELHI          4
# CHANDIGARH     3
# Name: CITYNAMES, dtype: int64

# %%
mumbai_df = pd.concat([city_count, city_name_mumbai], axis='columns', sort=False)

# %%
mumbai_df.head(50)
# Out:
#                       CITYNAMES  CITYNAMES
# MUMBAI                     47.0        NaN
# KANPUR                     11.0        NaN
# CHENNAI                     8.0        NaN
# INDORE                      8.0        NaN
# JAIPUR                      7.0        NaN
# AGRA                        7.0        NaN
# BANGLORE                    7.0        NaN
# GUWAHATI                    6.0        NaN
# NOIDA                       6.0        NaN
# GUJARAT                     6.0        NaN
# KERALA                      6.0        NaN
# SIKKIM                      6.0        NaN
# PUNE                        5.0        NaN
# HYDERABAD                   5.0        NaN
# DELHI                       4.0        NaN
# CHANDIGARH                  3.0        NaN
# ACTIVE-WEAR                 NaN        0.0
# AROMAS AND CANDLES          NaN        0.0
# BAKERWARE                   NaN        0.0
# BATHROOM ACCESSORIES        NaN        2.0
# BLANKETS                    NaN        1.0
# ...

# %%
#### python_df[''] = (python_df['']/python_df[''])*100

### python_df.sort_values(by='', ascending=False, inplace=True)

### python_df.loc['']

# %%
#----------------CLEANING DATA --- CASTING DATATYPES AND HANDLING MISSING VALUES ---------------#

# %%
import numpy as np

# %%
people = {
    'first':  ['Corey', 'Jane', 'John', np.nan, None, 'NA'],
    'last': ['Schafer', 'Doe', 'Doe', np.nan, np.nan, 'Missing'],
    'email':  ['CoreySchafer@gmail.com', 'JaneDoe@gmail.com', 'JohnDoe@gmail.com', None, np.nan, 'Anonymous@gmail.com'],
    'age':  ['33', '55', '63', None, None, 'Missing']
}

# %%
df3 = pd.DataFrame(people)

# %%
df3
# Out:
#    first     last                   email      age
# 0  Corey  Schafer  CoreySchafer@gmail.com       33
# 1   Jane      Doe       JaneDoe@gmail.com       55
# 2   John      Doe       JohnDoe@gmail.com       63
# 3    NaN      NaN                    None     None
# 4   None      NaN                     NaN     None
# 5     NA  Missing     Anonymous@gmail.com  Missing

# %%
df3.dropna()
# Out:
#    first     last                   email      age
# 0  Corey  Schafer  CoreySchafer@gmail.com       33
# 1   Jane      Doe       JaneDoe@gmail.com       55
# 2   John      Doe       JohnDoe@gmail.com       63
# 5     NA  Missing     Anonymous@gmail.com  Missing

# %%
##axis --- index or column ---row or column
## how --- any or all

df3
# Out:
#    first     last                   email      age
# 0  Corey  Schafer  CoreySchafer@gmail.com       33
# 1   Jane      Doe       JaneDoe@gmail.com       55
# 2   John      Doe       JohnDoe@gmail.com       63
# 3    NaN      NaN                    None     None
# 4   None      NaN                     NaN     None
# 5     NA  Missing     Anonymous@gmail.com  Missing

# %%
df3.dropna(axis='index', how='any')
df3.dropna(axis='index', how='all')
df3.dropna(axis='columns', how='all')
df3.dropna(axis='columns', how='any')

# df3.dropna(thresh=2) ---- not gonna drop that R/C if it has that many fields as not null
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5]

# %%
#ffill is forward fill is carry forwards previous values rather than filling it as 0
new_df1 = df3.fillna(method = "ffill")
new_df1

new_df1 = df3.fillna(method = "bfill")
new_df1

##axis="columns" to carry forward values from columns
##limit=N to how many rows/columns to carry forward
# Out:
#    first     last                   email   age
# 0  Corey  Schafer  CoreySchafer@gmail.com  33.0
# 1   Jane      Doe       JaneDoe@gmail.com  55.0
# 2   John      Doe       JohnDoe@gmail.com  63.0
# 3    NaN      NaN     Anonymous@gmail.com   NaN
# 4    NaN      NaN     Anonymous@gmail.com   NaN
# 5    NaN      NaN     Anonymous@gmail.com   NaN

# %%
##fill better estimated values 
new_df = df3.interpolate()
# new_df = df3.interpolate(method="time") relative to time

new_df
# Out:
#    first     last                   email   age
# 0  Corey  Schafer  CoreySchafer@gmail.com  33.0
# 1   Jane      Doe       JaneDoe@gmail.com  55.0
# 2   John      Doe       JohnDoe@gmail.com  63.0
# 3    NaN      NaN                    None  63.0
# 4   None      NaN                     NaN  63.0
# 5    NaN      NaN     Anonymous@gmail.com  63.0

# %%
df3
# Out:
#    first     last                   email      age
# 0  Corey  Schafer  CoreySchafer@gmail.com       33
# 1   Jane      Doe       JaneDoe@gmail.com       55
# 2   John      Doe       JohnDoe@gmail.com       63
# 3    NaN      NaN                    None     None
# 4   None      NaN                     NaN     None
# 5     NA  Missing     Anonymous@gmail.com  Missing

# %%
df3.dropna(axis='index', how='any', subset=['email'])
##gonna look at email only for missing values
# Out:
#    first     last                   email      age
# 0  Corey  Schafer  CoreySchafer@gmail.com       33
# 1   Jane      Doe       JaneDoe@gmail.com       55
# 2   John      Doe       JohnDoe@gmail.com       63
# 5     NA  Missing     Anonymous@gmail.com  Missing

# %%
df3.dropna(axis='index', how='all', subset=['last', 'email'])
# Out:
#    first     last                   email      age
# 0  Corey  Schafer  CoreySchafer@gmail.com       33
# 1   Jane      Doe       JaneDoe@gmail.com       55
# 2   John      Doe       JohnDoe@gmail.com       63
# 5     NA  Missing     Anonymous@gmail.com  Missing

# %%
df3
# Out:
#    first     last                   email      age
# 0  Corey  Schafer  CoreySchafer@gmail.com       33
# 1   Jane      Doe       JaneDoe@gmail.com       55
# 2   John      Doe       JohnDoe@gmail.com       63
# 3    NaN      NaN                    None     None
# 4   None      NaN                     NaN     None
# 5     NA  Missing     Anonymous@gmail.com  Missing

# %%
df3.append({'first': np.nan, 'last': None, 'email': np.nan, 'age': None}, ignore_index=True)
# Out:
# <ipython-input-173-75a8dd8d9aa0>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df3.append({'first': np.nan, 'last': None, 'email': np.nan, 'age': None}, ignore_index=True)
#    first     last                   email      age
# 0  Corey  Schafer  CoreySchafer@gmail.com       33
# 1   Jane      Doe       JaneDoe@gmail.com       55
# 2   John      Doe       JohnDoe@gmail.com       63
# 3    NaN      NaN                    None     None
# 4   None      NaN                     NaN     None
# 5     NA  Missing     Anonymous@gmail.com  Missing
# 6    NaN      NaN                     NaN      NaN

# %%
df3.replace('NA', np.nan, inplace=True)

df3.replace('Missing', np.nan, inplace=True)

# %%
"""
new_df = df.replace({
    'temperature':'[A-Za-z]',
    'windspeed': '[A-Za-z]',
}, np.NaN)

new_df = df.replace({
    'temperature': -99999,
    'windspeed': -88888,
    'event': 0,
}, '', regex=True)

new_df = df.replace({
    -99999: np.Nan,
    'No Event': 'Sunny',
})

new_df = df.replace('[A-Za-z]', '', regex=True)
new_df
"""
# Out:
# "\nnew_df = df.replace({\n    'temperature':'[A-Za-z]',\n    'windspeed': '[A-Za-z]',\n}, np.NaN)\n\nnew_df = df.replace({\n    'temperature': -99999,\n    'windspeed': -88888,\n    'event': 0,\n}, '', regex=True)\n\nnew_df = df.replace({\n    -99999: np.Nan,\n    'No Event': 'Sunny',\n})\n\nnew_df = df.replace('[A-Za-z]', '', regex=True)\nnew_df\n"

# %%
df3
# Out:
#    first     last                   email   age
# 0  Corey  Schafer  CoreySchafer@gmail.com    33
# 1   Jane      Doe       JaneDoe@gmail.com    55
# 2   John      Doe       JohnDoe@gmail.com    63
# 3    NaN      NaN                    None  None
# 4   None      NaN                     NaN  None
# 5    NaN      NaN     Anonymous@gmail.com   NaN

# %%
df3.isna()
# Out:
#    first   last  email    age
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3   True   True   True   True
# 4   True   True   True   True
# 5   True   True  False   True

# %%
df3.fillna('MISSING')
# Out:
#      first     last                   email      age
# 0    Corey  Schafer  CoreySchafer@gmail.com       33
# 1     Jane      Doe       JaneDoe@gmail.com       55
# 2     John      Doe       JohnDoe@gmail.com       63
# 3  MISSING  MISSING                 MISSING  MISSING
# 4  MISSING  MISSING                 MISSING  MISSING
# 5  MISSING  MISSING     Anonymous@gmail.com  MISSING

# %%
df3.fillna(0)
# Out:
#    first     last                   email age
# 0  Corey  Schafer  CoreySchafer@gmail.com  33
# 1   Jane      Doe       JaneDoe@gmail.com  55
# 2   John      Doe       JohnDoe@gmail.com  63
# 3      0        0                       0   0
# 4      0        0                       0   0
# 5      0        0     Anonymous@gmail.com   0

# %%
df3.dtypes
# Out:
# first    object
# last     object
# email    object
# age      object
# dtype: object

# %%
df3['age'].mean()

###because of NAN values ----> gonna be error ---> NAN is a float internally
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-181-ce5be5ed42fa> in <cell line: 1>()
# ----> 1 df3['age'].mean()
#       2
#       3 ###because of NAN values ----> gonna be error ---> NAN is a float internally
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11845             **kwargs,
#   11846         ):
# > 11847             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11848
#   11849         setattr(cls, "mean", mean)
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11399         **kwargs,
#   11400     ) -> Series | float:
# > 11401         return self._stat_function(
#   11402             "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
# ...

# %%
type(np.nan)
# Out:
# float

# %%
df3['age'] = df3['age'].astype(int) ##bcoz NAN values
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-184-68f9e19554b3> in <cell line: 1>()
# ----> 1 df3['age'] = df3['age'].astype(int) ##bcoz NAN values
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6238         else:
#    6239             # else, only a single dtype is given
# -> 6240             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241             return self._constructor(new_data).__finalize__(self, method="astype")
#    6242
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     446
#     447     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     449
#     450     def convert(
#
# ...

# %%
df3['age'] = df3['age'].astype(float) ##bcoz NAN values

# %%
df3.dtypes
# Out:
# first     object
# last      object
# email     object
# age      float64
# dtype: object

# %%
df3['age'].mean()
# Out:
# 50.333333333333336

# %%
df4 = pd.read_csv('/content/drive/MyDrive/sample_data/stack-overflow-developer-survey-2022/survey_results_public.csv')

# %%
df4
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                                      None of these
# 1               2                     I am a developer by profession
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 0                                                    NaN
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73268 entries, 0 to 73267
# Data columns (total 79 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ResponseId                      73268 non-null  int64
#  1   MainBranch                      73268 non-null  object
#  2   Employment                      71709 non-null  object
#  3   RemoteWork                      58958 non-null  object
#  4   CodingActivities                58899 non-null  object
#  5   EdLevel                         71571 non-null  object
#  6   LearnCode                       71580 non-null  object
#  7   LearnCodeOnline                 50685 non-null  object
#  8   LearnCodeCoursesCert            29389 non-null  object
#  9   YearsCode                       71331 non-null  object
#  10  YearsCodePro                    51833 non-null  object
#  11  DevType                         61302 non-null  object
# ...

# %%
df4['YearsCode'].head(15)
# Out:
# 0     NaN
# 1     NaN
# 2      14
# 3      20
# 4       8
# 5      15
# 6       3
# 7       1
# 8       6
# 9      37
# 10      5
# 11     12
# 12     12
# 13     22
# 14     11
# Name: YearsCode, dtype: object

# %%
df4['YearsCode'] = df4['YearsCode'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-194-3a5a4958d378> in <cell line: 1>()
# ----> 1 df4['YearsCode'] = df4['YearsCode'].astype(float)
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6238         else:
#    6239             # else, only a single dtype is given
# -> 6240             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241             return self._constructor(new_data).__finalize__(self, method="astype")
#    6242
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     446
#     447     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     449
#     450     def convert(
#
# ...

# %%
df4['YearsCode'].unique()
# Out:
# array([nan, '14', '20', '8', '15', '3', '1', '6', '37', '5', '12', '22',
#        '11', '4', '7', '13', '36', '2', '25', '10', '40', '16', '27',
#        '24', '19', '9', '17', '18', '26', 'More than 50 years', '29',
#        '30', '32', 'Less than 1 year', '48', '45', '38', '39', '28', '23',
#        '43', '21', '41', '35', '50', '33', '31', '34', '46', '44', '42',
#        '47', '49'], dtype=object)

# %%
df4['YearsCode'].replace('More than 50 years', 0, inplace=True)

# %%
df4['YearsCode'].replace('Less than 1 year', 0, inplace=True)

# %%
df4['YearsCode'] = df4['YearsCode'].astype(float)

# %%
df4['YearsCode'].mean()
# Out:
# 12.12833130055656

# %%
df4['YearsCode'].median()
# Out:
# 9.0

# %%
################## Dates and Time Series Data #################################

# %%
##convert each string into Date/Time object or parse it once you load it
d_parser = lambda x: pd.datetime.strptime(x,'%Y-%m-%d %I-%p')

df5 = pd.read_csv('/content/drive/MyDrive/sample_data/ETH.csv', parse_dates=['Date'], date_parser=d_parser)

##or 

#df5 = pd.read_csv('/content/drive/MyDrive/sample_data/ETH.csv')
# Out:
# <ipython-input-203-c2675beb0d86>:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   d_parser = lambda x: pd.datetime.strptime(x,'%Y-%m-%d %I-%p')

# %%
df5.head()

#this data is broken down in 1hr segments
# Out:
#                  Date  Symbol    Open    High     Low   Close      Volume
# 0 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %%
##number of rows and columns

df5.shape
# Out:
# (23674, 7)

# %%
df5.loc[0, 'Date']
# Out:
# Timestamp('2020-03-13 20:00:00')

# %%
#to find what day it is ---> convert it into Date/Time
df5.loc[0, 'Date'].day_name()
# Out:
# 'Friday'

# %%
##based on format it was in need to give format

df5['Date'] = pd.to_datetime(df5['Date'], format='%Y-%m-%d %I-%p')

# %%
df5['Date']
# Out:
# 0       2020-03-13 20:00:00
# 1       2020-03-13 19:00:00
# 2       2020-03-13 18:00:00
# 3       2020-03-13 17:00:00
# 4       2020-03-13 16:00:00
#                 ...
# 23669   2017-07-01 15:00:00
# 23670   2017-07-01 14:00:00
# 23671   2017-07-01 13:00:00
# 23672   2017-07-01 12:00:00
# 23673   2017-07-01 11:00:00
# Name: Date, Length: 23674, dtype: datetime64[ns]

# %%
df5.loc[0, 'Date'].day_name()
# Out:
# 'Friday'

# %%
### dt class
###can apply to entire series object

df5['Date'].dt.day_name()
# Out:
# 0          Friday
# 1          Friday
# 2          Friday
# 3          Friday
# 4          Friday
#            ...
# 23669    Saturday
# 23670    Saturday
# 23671    Saturday
# 23672    Saturday
# 23673    Saturday
# Name: Date, Length: 23674, dtype: object

# %%
df5['DayOfWeek'] = df5['Date'].dt.day_name()

# %%
df5
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#       DayOfWeek
# ...

# %%
df5['Date'].min()
# Out:
# Timestamp('2017-07-01 11:00:00')

# %%
df5['Date'].max()
# Out:
# Timestamp('2020-03-13 20:00:00')

# %%
##time delta

df5['Date'].max() - df5['Date'].min()
# Out:
# Timedelta('986 days 09:00:00')

# %%
DateFilter = (df5['Date'] >= '2020')
df5[DateFilter]
# Out:
#                     Date  Symbol    Open    High     Low   Close      Volume  \
# 0    2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1    2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2    2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3    2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4    2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                  ...     ...     ...     ...     ...     ...         ...
# 1744 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 1745 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 1746 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 1747 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
# 1748 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
#
#       DayOfWeek
# 0        Friday
# ...

# %%
DateFilter = (df5['Date'] >= '2019') & (df5['Date'] < '2020')
df5[DateFilter]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 1749  2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 1750  2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 1751  2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 1752  2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 1753  2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#       DayOfWeek
# ...

# %%
DateFilter = (df5['Date'] >= pd.to_datetime('2019')) & (df5['Date'] < pd.to_datetime('2020'))
df5[DateFilter]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 1749  2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 1750  2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 1751  2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 1752  2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 1753  2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#       DayOfWeek
# ...

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23674 entries, 0 to 23673
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       23674 non-null  datetime64[ns]
#  1   Symbol     23674 non-null  object
#  2   Open       23674 non-null  float64
#  3   High       23674 non-null  float64
#  4   Low        23674 non-null  float64
#  5   Close      23674 non-null  float64
#  6   Volume     23674 non-null  float64
#  7   DayOfWeek  23674 non-null  object
# dtypes: datetime64[ns](1), float64(5), object(2)
# memory usage: 1.4+ MB

# %%
df5.set_index('Date', inplace=True)

# %%
df5
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                     ...     ...     ...     ...     ...         ...
# 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#                     DayOfWeek
# Date
# 2020-03-13 20:00:00    Friday
# ...

# %%
df5['2019']
# Out:
# <ipython-input-223-c0f6c08b23de>:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df5['2019']
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                     ...     ...     ...     ...     ...         ...
# 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# ...

# %%
df5['2020-01':'2020-02']
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-02-29 23:00:00  ETHUSD  223.35  223.58  216.83  217.31  1927939.88
# 2020-02-29 22:00:00  ETHUSD  223.48  223.59  222.14  223.35   535998.57
# 2020-02-29 21:00:00  ETHUSD  224.63  225.14  222.74  223.48   561158.03
# 2020-02-29 20:00:00  ETHUSD  225.31  225.33  223.50  224.63   511648.65
# 2020-02-29 19:00:00  ETHUSD  225.09  225.85  223.87  225.31  1250856.20
# ...                     ...     ...     ...     ...     ...         ...
# 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
# 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
#
#                      DayOfWeek
# Date
# 2020-02-29 23:00:00   Saturday
# ...

# %%
df5['2020-01':'2020-02']['Close']
# Out:
# Date
# 2020-02-29 23:00:00    217.31
# 2020-02-29 22:00:00    223.35
# 2020-02-29 21:00:00    223.48
# 2020-02-29 20:00:00    224.63
# 2020-02-29 19:00:00    225.31
#                         ...
# 2020-01-01 04:00:00    129.56
# 2020-01-01 03:00:00    129.57
# 2020-01-01 02:00:00    130.37
# 2020-01-01 01:00:00    130.14
# 2020-01-01 00:00:00    128.34
# Name: Close, Length: 1440, dtype: float64

# %%
df5['2020-01':'2020-02']['Close'].mean()
# Out:
# 195.1655902777778

# %%
df5['2020-01':'2020-02'].head(20)
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-02-29 23:00:00  ETHUSD  223.35  223.58  216.83  217.31  1927939.88
# 2020-02-29 22:00:00  ETHUSD  223.48  223.59  222.14  223.35   535998.57
# 2020-02-29 21:00:00  ETHUSD  224.63  225.14  222.74  223.48   561158.03
# 2020-02-29 20:00:00  ETHUSD  225.31  225.33  223.50  224.63   511648.65
# 2020-02-29 19:00:00  ETHUSD  225.09  225.85  223.87  225.31  1250856.20
# 2020-02-29 18:00:00  ETHUSD  225.53  226.17  224.50  225.09   496543.91
# 2020-02-29 17:00:00  ETHUSD  222.68  225.53  222.24  225.53   611136.47
# 2020-02-29 16:00:00  ETHUSD  224.17  225.93  222.36  222.68   694384.75
# 2020-02-29 15:00:00  ETHUSD  223.35  225.88  221.80  224.17   550893.74
# 2020-02-29 14:00:00  ETHUSD  224.42  224.42  221.15  223.35  1479928.44
# 2020-02-29 13:00:00  ETHUSD  225.29  225.37  222.87  224.42  1076646.41
# 2020-02-29 12:00:00  ETHUSD  226.50  226.50  224.14  225.29   359022.09
# ...

# %%
df5['2020-01-01']['High']
# Out:
# <ipython-input-228-bceed789e10d>:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df5['2020-01-01']['High']
# Date
# 2020-01-01 23:00:00    130.27
# 2020-01-01 22:00:00    131.41
# 2020-01-01 21:00:00    131.99
# 2020-01-01 20:00:00    131.87
# 2020-01-01 19:00:00    131.72
# 2020-01-01 18:00:00    132.14
# 2020-01-01 17:00:00    132.68
# 2020-01-01 16:00:00    132.56
# 2020-01-01 15:00:00    132.15
# 2020-01-01 14:00:00    132.05
# 2020-01-01 13:00:00    132.08
# 2020-01-01 12:00:00    131.31
# 2020-01-01 11:00:00    131.42
# 2020-01-01 10:00:00    130.33
# 2020-01-01 09:00:00    130.22
# 2020-01-01 08:00:00    130.01
# 2020-01-01 07:00:00    130.25
# 2020-01-01 06:00:00    130.25
# 2020-01-01 05:00:00    129.94
# 2020-01-01 04:00:00    130.00
# 2020-01-01 03:00:00    130.44
# 2020-01-01 02:00:00    130.50
# ...

# %%
df5['2020-01-01']['High'].max()
# Out:
# <ipython-input-229-72183d602bcb>:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df5['2020-01-01']['High'].max()
# 132.68

# %%
####resample data ------High value by Day

highs = df5['High'].resample('D').max()

highs['2020-01-01']
# Out:
# 132.68

# %%
# %matplotlib inline

# %%
highs.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
##Resample multiple columns at once ?? --->resample on entire dataframe instead of single series

#multiple columns and multiple aggregation function

df5.resample('W').mean()
# Out:
# <ipython-input-233-8670c417a170>:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df5.resample('W').mean()
#                   Open        High         Low       Close        Volume
# Date
# 2017-07-02  268.066486  271.124595  264.819730  268.202162  2.185035e+06
# 2017-07-09  261.337024  262.872917  259.186190  261.062083  1.337349e+06
# 2017-07-16  196.193214  199.204405  192.722321  195.698393  2.986756e+06
# 2017-07-23  212.351429  215.779286  209.126310  212.783750  4.298593e+06
# 2017-07-30  203.496190  205.110357  201.714048  203.309524  1.581729e+06
# ...                ...         ...         ...         ...           ...
# 2020-02-16  255.021667  257.255238  252.679762  255.198452  2.329087e+06
# 2020-02-23  265.220833  267.263690  262.948512  265.321905  1.826094e+06
# ...

# %%
###AGG accepts ---> multiple columns and multipe agg functions 

##https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior
##https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#dateoffset-objects

df5.resample('W').agg({'Close': 'mean', 'High': 'max', 'Low': 'min', 'Volume': 'sum'})
# Out:
#                  Close    High     Low        Volume
# Date
# 2017-07-02  268.202162  293.73  253.23  8.084631e+07
# 2017-07-09  261.062083  285.00  231.25  2.246746e+08
# 2017-07-16  195.698393  240.33  130.26  5.017750e+08
# 2017-07-23  212.783750  249.40  153.25  7.221637e+08
# 2017-07-30  203.309524  229.99  178.03  2.657305e+08
# ...                ...     ...     ...           ...
# 2020-02-16  255.198452  290.00  216.31  3.912867e+08
# 2020-02-23  265.321905  287.13  242.36  3.067838e+08
# 2020-03-01  236.373988  278.13  209.26  3.693920e+08
# 2020-03-08  229.817619  253.01  196.00  2.736569e+08
# 2020-03-15  176.332821  208.65   90.00  4.983998e+08
#
# [142 rows x 4 columns]

# %%
## Reading / Writing Data to Different Sources - Excel, Json, SQL

df6 = pd.read_csv('/content/drive/MyDrive/sample_data/stack-overflow-developer-survey-2022/survey_results_public.csv', index_col='ResponseId')

# %%
df6
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                                               None of these
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 73264                          I am a developer by profession
# 73265                          I am a developer by profession
# 73266       I am not primarily a developer, but I write co...
# 73267                          I am a developer by profession
# 73268       I used to be a developer by profession, but no...
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# ...

# %%
filterCsv = (df6['Country'] == 'India')
india_df = df6[filterCsv]
india_df
# Out:
#                                                    MainBranch  \
# ResponseId
# 7                                 I code primarily as a hobby
# 8                              I am a developer by profession
# 66                             I am a developer by profession
# 141                            I am a developer by profession
# 152                            I am a developer by profession
# ...                                                       ...
# 73185                          I am a developer by profession
# 73194       I used to be a developer by profession, but no...
# 73256                          I am a developer by profession
# 73258                                   I am learning to code
# 73259                          I am a developer by profession
#
#                                     Employment  \
# ResponseId
# 7                           Student, part-time
# 8           Not employed, but looking for work
# 66                         Employed, full-time
# ...

# %%
india_df.to_csv('/content/drive/MyDrive/sample_data/query-sample.csv')

# %%
india_df.to_csv('/content/drive/MyDrive/sample_data/query-sample.tsv', sep='\t')

# %%
##EXCEL

# !pip install xlwt openpyxl xlrd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
india_df.to_excel('/content/drive/MyDrive/sample_data/query-sample.xlsx')

# %%
test = pd.read_excel('/content/drive/MyDrive/sample_data/query-sample.xlsx', index_col='ResponseId')

"""after file path, "sheet name can be given as another parameter"
test = pd.read_excel('/content/drive/MyDrive/sample_data/query-sample.xlsx', " ", index_col='ResponseId')
"""
# Out:
# 'after file path, "sheet name can be given as another parameter"\ntest = pd.read_excel(\'/content/drive/MyDrive/sample_data/query-sample.xlsx\', " ", index_col=\'ResponseId\')\n'

# %%
test.head()
# Out:
#                                 MainBranch  \
# ResponseId
# 7              I code primarily as a hobby
# 8           I am a developer by profession
# 66          I am a developer by profession
# 141         I am a developer by profession
# 152         I am a developer by profession
#
#                                     Employment  \
# ResponseId
# 7                           Student, part-time
# 8           Not employed, but looking for work
# 66                         Employed, full-time
# 141                        Employed, full-time
# 152                        Employed, full-time
#
#                                       RemoteWork  \
# ResponseId
# 7                                            NaN
# 8                                            NaN
# 66          Hybrid (some remote, some in-person)
# 141         Hybrid (some remote, some in-person)
# 152                               Full in-person
#
#                          CodingActivities  \
# ResponseId
# ...

# %%
import numpy as np

def convert_people_cell(cell):
  if cell == "n.a.":
    return 'sam walton'
  return cell


test1 = pd.read_excel('/content/drive/MyDrive/sample_data/query-sample.xlsx', "Sheet1", converters={
    'RemoteWork': convert_people_cell,
    'CodingActivites': convert_people_cell
})

test1
# Out:
#       ResponseId                                         MainBranch  \
# 0              7                        I code primarily as a hobby
# 1              8                     I am a developer by profession
# 2             66                     I am a developer by profession
# 3            141                     I am a developer by profession
# 4            152                     I am a developer by profession
# ...          ...                                                ...
# 6634       73185                     I am a developer by profession
# 6635       73194  I used to be a developer by profession, but no...
# 6636       73256                     I am a developer by profession
# 6637       73258                              I am learning to code
# 6638       73259                     I am a developer by profession
#
#                               Employment  \
# 0                     Student, part-time
# 1     Not employed, but looking for work
# ...

# %%
#    india_df.to_excel('/content/drive/MyDrive/sample_data/query-sample.xlsx', sheet_name="", startrow=1, startcol=2, index=False)

# %%
"""
with pd.ExcelWriter('') as writer:
  df_stocks.to_excel(writer, sheet_name="")
  df_weather.to_excel(writer, sheet_name="")
"""
# Out:
# '\nwith pd.ExcelWriter(\'\') as writer:\n  df_stocks.to_excel(writer, sheet_name="")\n  df_weather.to_excel(writer, sheet_name="")\n'

# %%
###JSON

india_df.to_json('/content/drive/MyDrive/sample_data/query-sample.json')

# %%
india_df.to_json('/content/drive/MyDrive/sample_data/query-sample1.json', orient='records', lines=True)

# %%
test = pd.read_json('/content/drive/MyDrive/sample_data/query-sample1.json', orient='records', lines=True)

# %%
## posts_Df = pd.read_json('url-to-the-json-file-location')
## posts_Df.head()

# %%
test.head()
# Out:
#                        MainBranch                          Employment  \
# 0     I code primarily as a hobby                  Student, part-time
# 1  I am a developer by profession  Not employed, but looking for work
# 2  I am a developer by profession                 Employed, full-time
# 3  I am a developer by profession                 Employed, full-time
# 4  I am a developer by profession                 Employed, full-time
#
#                              RemoteWork               CodingActivities  \
# 0                                  None                           None
# 1                                  None                           None
# 2  Hybrid (some remote, some in-person)  Hobby;Other (please specify):
# 3  Hybrid (some remote, some in-person)   I don’t code outside of work
# 4                        Full in-person                          Hobby
#
#                                              EdLevel  \
# 0  Secondary school (e.g. American high school, G...
# ...

# %%
##for Sql ----> SQLAlchemy,  psycopg2-binary

"""
from sqlalchemy import create_engine
import psycopg2

engine = create_engine('')    #username-pswrd-port

india_df.to_sql('table-name', engine, if_exists='replace')

sql_df = pd.read_sql('table-name', engine, index_col='index-col-name')

sql_df.head()

sql_df = pd.read_sql_query('query', engine, index_col='index-col-name')

sql_df.head()

"""
# Out:
# "\nfrom sqlalchemy import create_engine\nimport psycopg2\n\nengine = create_engine('')    #username-pswrd-port\n\nindia_df.to_sql('table-name', engine, if_exists='replace')\n\nsql_df = pd.read_sql('table-name', engine, index_col='index-col-name')\n\nsql_df.head()\n\nsql_df = pd.read_sql_query('query', engine, index_col='index-col-name')\n\nsql_df.head()\n\n"

# %%
df
# Out:
#      ORDERID  ORDERDATE   SHIPDATE      SHIPMODE  CUSTOMERID  CATEGORY  \
# 100       48  3/14/2023  3/23/2023      STANDARD         234  APPARELS
# 104       61  3/14/2023  3/19/2023      STANDARD         349  APPARELS
# 72       147  3/14/2023  3/21/2023  SECOND CLASS         130  APPARELS
# 3         23  3/14/2023  3/20/2023   FIRST CLASS         158  APPARELS
# 8         55  3/14/2023  3/22/2023  SECOND CLASS         115  APPARELS
# ..       ...        ...        ...           ...         ...       ...
# 39       112  3/14/2023  3/20/2023      STANDARD         302  APPARELS
# 90       161  3/14/2023  3/21/2023  SECOND CLASS         146  APPARELS
# 101       51  3/14/2023  3/24/2023  SECOND CLASS         182  APPARELS
# 25        21  3/14/2023  3/20/2023   FIRST CLASS         250  APPARELS
# 4         36  3/14/2023  3/20/2023      STANDARD         364  APPARELS
#
#       CITYNAMES COUNTRY  POSTALCODE            ITEM  QUANTITY  COST  TOTAL  \
# ...

# %%
"""
generate range 

dt = pd.date_range("01-01-2023", "01-011-2023")
idx = pd.DatetimeIndex(dt)
df.reindex(idx)
df
"""
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# /usr/local/lib/python3.9/dist-packages/dateutil/parser/_parser.py in parse(timestr, parserinfo, **kwargs)
#    1367     else:
# -> 1368         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1369
#
# /usr/local/lib/python3.9/dist-packages/dateutil/parser/_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     642         if res is None:
# --> 643             raise ParserError("Unknown string format: %s", timestr)
#     644
#
# ParserError: Unknown string format: 01-011-2023
#
# During handling of the above exception, another exception occurred:
#
# ...
